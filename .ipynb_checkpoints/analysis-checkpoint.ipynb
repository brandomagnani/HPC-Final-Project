# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 16

# %%
path = '/home/aeb783/HPC-Final-Project/'

# %% [markdown]
# Read sgd datasets

# %%
n_threads = 8
thread_counts = np.arange(1, n_threads+1)
# thread_counts = 2**np.arange(6, dtype=int)
thread_counts
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
dfs = {
    '{}_threads'.format(i) : pd.read_csv(path + 'output/{}_threads_sgd.csv'.format(i))
    for i in thread_counts
}
dfs['2_threads']
# Out:
#     residual_norm   runtime         flops
# 0    2.275434e+07  0.100937  1.189207e+09
# 1    1.140237e+10  0.167955  7.146865e+08
# 2    5.699957e+12  0.235048  5.106842e+08
# 3    2.849351e+15  0.298404  4.022571e+08
# 4    1.424361e+18  0.364953  3.289057e+08
# ..            ...       ...           ...
# 95            inf  6.409703  1.872708e+07
# 96            inf  6.496495  1.847689e+07
# 97            inf  6.562485  1.829109e+07
# 98            inf  6.626311  1.811491e+07
# 99            inf  6.689288  1.794436e+07
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Residual norm vs iteration

# %%
fig, ax = plt.subplots(figsize=(12,8))

for i in thread_counts:
    df = dfs['{}_threads'.format(i)]
    
    ax.semilogy(df['residual_norm'], label='n_threads={}'.format(i))
    
ax.set(
    xlabel='Iteration',
    ylabel='Residual norm',
    title='Residual norm by iteration',
)

ax.legend();

# %%
fig, ax = plt.subplots(figsize=(12,8))

for i in thread_counts:
    df = dfs['{}_threads'.format(i)]
    
    ax.semilogy(df['residual_norm'], label='n_threads={}'.format(i))
    
ax.set(
    xlabel='Iteration',
    ylabel='Residual norm',
    title='Residual norm by iteration',
)

ax.legend();

# %% [markdown]
# ## Residual norm by time

# %%
fig, ax = plt.subplots(figsize=(12,8))

for i in thread_counts:
    df = dfs['{}_threads'.format(i)]
    x = df['runtime']
    y = df['residual_norm']
    
    ax.semilogy(x, y, label='n_threads={}'.format(i))
    
ax.set(
    xlabel='Time (s)',
    ylabel='Residual norm',
    title='Residual norm vs time',
    xlim=(0,10)
)

ax.legend();

# %% [markdown]
# ## Time for convergence

# %%
plt.plot();
plt.xticks(thread_counts);
plt.ylim(0,200);
plt.xlabel('Number of threads');
plt.ylabel('Simulation time (s)');
plt.title(r'Time to convergence (tol=$10^{-6}$)');

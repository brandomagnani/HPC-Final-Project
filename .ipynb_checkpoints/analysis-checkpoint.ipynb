# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 16

# %%
path = '/home/aeb783/HPC-Final-Project/'

# %% [markdown]
# Read sgd datasets

# %%
n_threads = 8
# thread_counts = np.arange(1, n_threads+1)
thread_counts = 2**np.arange(6, dtype=int)
thread_counts
# Out:
# array([ 1,  2,  4,  8, 16, 32])

# %%
dfs = {
    '{}_threads'.format(i) : pd.read_csv(path + 'output/{}_threads_sgd.csv'.format(i))
    for i in thread_counts
}
dfs['8_threads']
# Out:
#      residual_norm     runtime
# 0    780819.125000    0.000000
# 1    683816.250000    1.563726
# 2    601659.625000    3.158536
# 3    526653.437500    4.682169
# 4    462018.312500    6.547040
# ..             ...         ...
# 96        7.589598  163.425082
# 97        6.740855  165.115979
# 98        5.971284  166.799373
# 99        5.298815  168.433226
# 100       4.714039  170.109270
#
# [101 rows x 2 columns]

# %% [markdown]
# ## Residual norm vs iteration

# %%
fig, ax = plt.subplots(figsize=(12,8))

for i in thread_counts:
    df = dfs['{}_threads'.format(i)]
    
    ax.semilogy(df['residual_norm'], label='n_threads={}'.format(i))
    
ax.set(
    xlabel='Iteration',
    ylabel='Residual norm',
    title='Residual norm by iteration',
)

ax.legend();

# %% [markdown]
# ## Residual norm by time

# %%
fig, ax = plt.subplots(figsize=(12,8))

for i in thread_counts:
    df = dfs['{}_threads'.format(i)]
    x = df['runtime']
    y = df['residual_norm']
    
    ax.semilogy(x, y, label='n_threads={}'.format(i))
    
ax.set(
    xlabel='Time (s)',
    ylabel='Residual norm',
    title='Residual norm vs time',
)

ax.legend();

# %% [markdown]
# ## Time for convergence

# %%
plt.plot();
plt.xticks(thread_counts);
plt.ylim(0,200);
plt.xlabel('Number of threads');
plt.ylabel('Simulation time (s)');
plt.title(r'Time to convergence (tol=$10^{-6}$)');
